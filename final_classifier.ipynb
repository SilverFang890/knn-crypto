# %%
# %run ./baseline_classifier.ipynb
# Out:
# Predicted Category: ['meme' 'layer1' 'meme' 'meme']
#   Correct Category: ['meme' 'layer1' 'layer1' 'layer1']
# Model Accuracy: 0.5
# Cross-Validation Scores: [1.   1.   0.5  0.75 0.75]
# Mean Accuracy: 0.8
# Standard Deviation: 0.18708286933869706

# %%
coins
# Out:
#                     05/30/2023    05/31/2023    06/01/2023    06/02/2023  \
# bitcoin           2.775975e+04  2.771391e+04  2.724547e+04  2.682410e+04
# ethereum          1.893714e+03  1.901078e+03  1.874695e+03  1.861725e+03
# binancecoin       3.115659e+02  3.116037e+02  3.070113e+02  3.049813e+02
# solana            2.057366e+01  2.124839e+01  2.082043e+01  2.051289e+01
# the-open-network  1.849149e+00  1.861388e+00  1.836295e+00  1.772151e+00
# cardano           3.790030e-01  3.779807e-01  3.750856e-01  3.651749e-01
# avalanche-2       1.448255e+01  1.444254e+01  1.413360e+01  1.411632e+01
# tron              7.614779e-02  7.646024e-02  7.533391e-02  7.482588e-02
# bitcoin-cash      1.149532e+02  1.141691e+02  1.132646e+02  1.133756e+02
# near              1.629078e+00  1.608966e+00  1.573629e+00  1.547119e+00
# dogecoin          7.326421e-02  7.239236e-02  7.176214e-02  7.156278e-02
# shiba-inu         8.738000e-06  8.694200e-06  8.564800e-06  8.482300e-06
# ...

# %%
knn_classifier
# Out:
# Pipeline(steps=[('rsi', RSITransformer()), ('scaler', StandardScaler()),
#                 ('knn', KNeighborsClassifier())])

# %%
knn_classifier.named_steps['knn'].kneighbors(
    knn_classifier.fit(X_train, y_train)[:2].transform(coins.loc[['bitcoin']].drop(columns='category'))
)
# Out:
# (array([[ 0.        , 80.0872741 , 80.11414715, 80.26943162, 80.49218037]]),
#  array([[13, 12,  1,  2,  4]]))

# %%
knn_classifier.predict(coins.loc[['bitcoin']].drop(columns='category'))[0]
# Out:
# 'layer1'
